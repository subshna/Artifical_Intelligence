# %%
import folium
from geopy.geocoders import Nominatim
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import requests

# %%
df = pd.read_csv('ca.csv')
df.head(10)
# Out:
#         city        lat         lng country iso2             admin  capital  \
# 0    Toronto  43.666667  -79.416667  Canada   CA           Ontario    admin
# 1   Montreal  45.500000  -73.583333  Canada   CA            Quebec      NaN
# 2  Vancouver  49.250000 -123.133333  Canada   CA  British Columbia      NaN
# 3     Ottawa  45.416667  -75.700000  Canada   CA           Ontario  primary
# 4    Calgary  51.083333 -114.083333  Canada   CA           Alberta      NaN
# 5   Edmonton  53.550000 -113.500000  Canada   CA           Alberta    admin
# 6   Hamilton  43.256101  -79.857484  Canada   CA           Ontario      NaN
# 7   Winnipeg  49.883333  -97.166667  Canada   CA          Manitoba    admin
# 8     Quebec  46.800000  -71.250000  Canada   CA            Quebec    admin
# 9     Oshawa  43.900000  -78.866667  Canada   CA           Ontario      NaN
#
#    population  population_proper
# 0     5213000            3934421
# 1     3678000            2356556
# 2     2313328             603502
# 3     1145000             812129
# 4     1110000             915322
# 5     1058000             712391
# 6      721053             519949
# 7      632063             575313
# 8      624177             528595
# 9      450963             247989

# %%
# Drop iso2, captial and population_proper
df.drop(['capital', 'population_proper'], axis=1, inplace=True)

# %%
# Rename admin to Province
df.rename(columns={'admin':'province'}, inplace=True)
df.head()
# Out:
#         city        lat         lng country iso2          province  population
# 0    Toronto  43.666667  -79.416667  Canada   CA           Ontario     5213000
# 1   Montréal  45.500000  -73.583333  Canada   CA            Québec     3678000
# 2  Vancouver  49.250000 -123.133333  Canada   CA  British Columbia     2313328
# 3     Ottawa  45.416667  -75.700000  Canada   CA           Ontario     1145000
# 4    Calgary  51.083333 -114.083333  Canada   CA           Alberta     1110000

# %%
# Define foursquare credentials and version
client_id = 'AUDP4MRVSHCP2RDWBPDWJSOSBUFMHCYPOMHY0W02ESKEBM4D'
client_secret = 'QRDC34SWN0ZARTH3I4MBOKPNIOYIPUAOYR01BILPQID3AIS1'
version = '20180604'
limit = 30

# %%
# Get the latitude and longitude for Canada
country = str(df.country[0])
country_code = str(df.iso2[0])
add = country + "," + country_code
add
geolocator = Nominatim()
location = geolocator.reverse(55.585901, -105.750596)
print (location.address)
#ca_lat = location.latitude
#ca_lng = location.longitude
#print ('Latitude and Longtide of Canada: ', ca_lat,  ca_lng)
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:6: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
# ---------------------------------------------------------------------------
# GeocoderTimedOut                          Traceback (most recent call last)
# <ipython-input-39-a7d0d7625dd0> in <module>()
#       5 add
#       6 geolocator = Nominatim()
# ----> 7 location = geolocator.reverse(55.585901, -105.750596)
#       8 print (location.address)
#       9 #ca_lat = location.latitude
#
# c:\python27\lib\site-packages\geopy\geocoders\osm.pyc in reverse(self, query, exactly_one, timeout, language, addressdetails)
#     369
#     370         return self._parse_json(
# --> 371             self._call_geocoder(url, timeout=timeout), exactly_one
#     372         )
#     373
#
# c:\python27\lib\site-packages\geopy\geocoders\base.pyc in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     365             elif isinstance(error, URLError):
#     366                 if "timed out" in message:
# --> 367                     raise GeocoderTimedOut('Service timed out')
#     368                 elif "unreachable" in message:
#     369                     raise GeocoderUnavailable('Service not available')
#
# GeocoderTimedOut: Service timed out

# %%
# Generate map around Canada
map_ca = folium.Map()

# Lets visualize the City using folium map
for lat, lng, label in zip(df.lat, df.lng, df.city):
    folium.features.CircleMarker(
    [lat, lng],
    radius = 5,
    color = 'red',
    popup = label,
    fill = True,
    fill_color = 'blue',
    )
