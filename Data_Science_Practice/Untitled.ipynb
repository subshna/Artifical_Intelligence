# %%
import pandas as pd

# %%
dataset = pd.read_excel('E:\Subash\MAIN-RANSTAD-PETER.xls')

# %%
dataset.head()
# Out:
#                                          COMBO  \
# 0  Deiva Saranya Ramesh Subramanian|43112|4360
# 1                Alvin Lonakutty|43112|1132.93
# 2                 Alvin Lonakutty|43112|212.42
# 3                 Sarathkumar  K|43112|1132.93
# 4                  Sarathkumar  K|43112|212.42
#
#                                          COMBO-1  Customer ID  \
# 0  Deiva Saranya Ramesh Subramanian|43112|4316.4   2000796123
# 1                   Alvin Lonakutty|43112|1121.6   2000796123
# 2                    Alvin Lonakutty|43112|210.3   2000796123
# 3                    Sarathkumar  K|43112|1121.6   2000796123
# 4                     Sarathkumar  K|43112|210.3   2000796123
#
#                 Cust. Name  Supplier ID Supplier Name  Invoice Number  \
# 0  DO NOT USE - WALMART/FG      1130732     Wipro LLC         6987265
# 1  DO NOT USE - WALMART/FG      1130732     Wipro LLC         6987793
# 2  DO NOT USE - WALMART/FG      1130732     Wipro LLC         6987791
# ...
